# %%
# %load_ext rpy2.ipython
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-a69f80d0128e> in <module>()
# ----> 1 get_ipython().magic('load_ext rpy2.ipython')
#
# C:\Users\thomas\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# C:\Users\thomas\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
# ...

# %%
# %%R
# X = c(1,2,3,4,5)
# Y = c(1,2,3,6,5)
# s = capture.output(summary(lm(Y~X)))

# %%
a =%R s
for line in a[2:-1]:
         print(line )

# %%
# %R plot(X,Y)
